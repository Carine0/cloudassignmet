# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('books.csv')

# %%
df.head()
# Out:
#    book_id  goodreads_book_id  best_book_id   work_id  books_count       isbn  \
# 0        1            2767052       2767052   2792775          272  439023483
# 1        2                  3             3   4640799          491  439554934
# 2        3              41865         41865   3212258          226  316015849
# 3        6           11870085      11870085  16827462          226  525478817
# 4       12           13335037      13335037  13155899          210   62024035
#
#          isbn13                      authors  original_publication_year  \
# 0  9.780439e+12              Suzanne Collins                     2008.0
# 1  9.780440e+12  J.K. Rowling, Mary GrandPré                     1997.0
# 2  9.780316e+12              Stephenie Meyer                     2005.0
# 3  9.780525e+12                   John Green                     2012.0
# 4  9.780062e+12                Veronica Roth                     2011.0
#
# ...

# %%
df.dropna(inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.shape
# Out:
# (1153, 23)

# %%
#number of books publishedd by year
books_per_year = df.groupby('original_publication_year')['book_id'].count()
books_per_year
# Out:
# original_publication_year
# 1871.0     1
# 1874.0     1
# 1876.0     1
# 1886.0     1
# 1908.0     1
#           ..
# 2013.0    64
# 2014.0    49
# 2015.0    32
# 2016.0    17
# 2017.0     2
# Name: book_id, Length: 81, dtype: int64

# %%
plt.hist(df['average_rating'], bins=20, color='skyblue', edgecolor='black')
plt.xlabel('Average Rating')
plt.ylabel('Frequency')
plt.title('Distribution of Average Ratings')
plt.show()

# %%
top_authors = df['authors'].value_counts().head(10)
top_authors
# Out:
# Meg Cabot          22
# Tamora Pierce      20
# L.J. Smith         14
# Sara Shepard       13
# Rick Riordan       12
# John Flanagan      12
# Sarah Dessen       12
# Richelle Mead      11
# Rachel Caine       10
# L.M. Montgomery    10
# Name: authors, dtype: int64

# %%
harry_potter_df = df[df['authors'].str.contains('J.K. Rowling') | df['authors'].str.contains('Mary GrandPré')]
harry_potter_df
# Out:
#      book_id  goodreads_book_id  best_book_id   work_id  books_count  \
# 1          2                  3             3   4640799          491
# 6         18                  5             5   2402163          376
# 8         21                  2             2   2809203          307
# 9         23              15881         15881   6231171          398
# 10        24                  6             6   3046572          332
# 11        25             136251        136251   2963218          263
# 12        27                  1             1  41335427          275
# 92       399            3950967       3950967   3007490          131
# 96       422             862041        862041   2962492           76
# 237     1286             111450        111450   6247751          103
# 613     3753                 10            10  21457570            6
#
#            isbn        isbn13                                  authors  \
# ...

# %%
average_rating = harry_potter_authors_df['ratings_count'].mean()
print("Average rating of Harry Potter books:", average_rating)
# Out:
# Average rating of Harry Potter books: 1428986.3636363635

# %%
total_sales = harry_potter_authors_df['ratings_count'].sum()
print("Total sales of Harry Potter books:", total_sales)
# Out:
# Total sales of Harry Potter books: 15718850

# %%
most_popular_book = harry_potter_authors_df.loc[harry_potter_authors_df['ratings_count'].idxmax()]
print("Most popular Harry Potter book:", most_popular_book['original_title'])
# Out:
# Most popular Harry Potter book: Harry Potter and the Philosopher's Stone
